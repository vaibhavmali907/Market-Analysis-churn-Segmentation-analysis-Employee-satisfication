# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
churn=pd.read_csv(r"churn_data.csv")

# %%
churn.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# 0           Electronic check           29.85        29.85    No  Female
# 1               Mailed check           56.95       1889.5    No    Male
# 2               Mailed check           53.85       108.15   Yes    Male
# 3  Bank transfer (automatic)           42.30      1840.75    No    Male
# 4           Electronic check           70.70       151.65   Yes  Female
#
#   InternetService
# 0             DSL
# 1             DSL
# 2             DSL
# 3             DSL
# 4     Fiber optic

# %%
churn.tail()
# Out:
#       customerID  tenure PhoneService        Contract PaperlessBilling  \
# 7038  6840-RESVB      24          Yes        One year              Yes
# 7039  2234-XADUH      72          Yes        One year              Yes
# 7040  4801-JZAZL      11           No  Month-to-month              Yes
# 7041  8361-LTMKD       4          Yes  Month-to-month              Yes
# 7042  3186-AJIEK      66          Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn  gender  \
# 7038               Mailed check           84.80       1990.5    No    Male
# 7039    Credit card (automatic)          103.20       7362.9    No  Female
# 7040           Electronic check           29.60       346.45    No  Female
# 7041               Mailed check           74.40        306.6   Yes    Male
# 7042  Bank transfer (automatic)          105.65       6844.5    No    Male
#
#      InternetService
# 7038             DSL
# 7039     Fiber optic
# ...

# %%
#checking for missing values
churn.isnull().sum()
# Out:
# customerID          0
# tenure              0
# PhoneService        0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# gender              0
# InternetService     0
# dtype: int64

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   PhoneService      7043 non-null   object
#  3   Contract          7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
#  8   Churn             7043 non-null   object
#  9   gender            7043 non-null   object
#  10  InternetService   7043 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 605.4+ KB

# %%
plt.figure(figsize=(10, 10))
g = sns.histplot(x='tenure', hue='Churn', data=churn)

# %%
plt.figure(figsize=(10, 10))
g = sns.boxplot(x='tenure', hue='MonthlyCharges', data=churn)

# %%
plt.figure(figsize=(10, 10))
g = sns.histplot(x='gender', hue='MonthlyCharges', data=churn)

# %%
plt.figure(figsize=(10, 10))
g = sns.histplot(x='Churn', hue='InternetService', data=churn)

# %%
internet=pd.read_csv(r'internet_data.csv')

# %%
internet.head()
# Out:
#    customerID     MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  7590-VHVEG  No phone service             DSL             No          Yes
# 1  5575-GNVDE                No             DSL            Yes           No
# 2  3668-QPYBK                No             DSL            Yes          Yes
# 3  7795-CFOCW  No phone service             DSL            Yes           No
# 4  9237-HQITU                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies Churn
# 0               No          No          No              No    No
# 1              Yes          No          No              No    No
# 2               No          No          No              No   Yes
# 3              Yes         Yes          No              No    No
# 4               No          No          No              No   Yes

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
internet[internet.select_dtypes(include=['object']).columns]=internet[internet.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
sns.catplot(x="OnlineSecurity", y="Churn", kind="bar", data=internet)

# %%
sns.catplot(x="OnlineBackup", y="Churn", kind="bar", data=internet)

# %%
sns.catplot(x="DeviceProtection", y="Churn", kind="bar", data=internet)

# %%
sns.catplot(x="TechSupport", y="Churn", kind="bar", data=internet)

# %%
sns.catplot(x="StreamingTV", y="Churn", kind="bar", data=internet)

# %%
sns.catplot(x="StreamingMovies", y="Churn", kind="bar", data=internet)

# %%
sns.displot(x="PaymentMethod", y="Churn", data=churn)

# %%
plt.figure(figsize=(10, 10))
g = sns.histplot(x='MonthlyCharges', hue='Churn', data=churn)

# %%
sns.catplot(x="InternetService", y="Churn", kind="bar", data=internet)

# %%
plt.figure(figsize=(10, 10))
g = sns.histplot(x='customerID', hue='Churn', data=churn)
